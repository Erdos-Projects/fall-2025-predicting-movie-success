# %%
import pandas as pd

# %%
df_1 = pd.read_csv('out.csv')
df_2 = pd.read_csv('user_award_reviews.csv')
df = pd.concat([df_1, df_2]).reset_index(drop=True)
df.drop_duplicates(inplace=True)
df.drop(columns=['wicked-2024', 'emilia-perez', 'i-tonya', 'the-banshees-of-inisherin', 'the-menu-2022.1', 'nightmare-alley-2021.1'], inplace=True)
df.to_csv('out.csv', index=False)

# %%
df_1 = pd.read_csv('out.csv')
df_2 = pd.read_csv('user_award_reviews.csv')

# %%
df_2
# Out:
#             username    anora  conclave the-brutalist emilia-perez  \
# 0                jay      3.5       3.5       Missing      Missing
# 1         deathproof      3.5  Late 4.0           4.5      Missing
# 2       davidehrlich      4.5       3.0           3.5          2.5
# 3           thejoshl      4.0       2.0           4.0          1.0
# 4    colonelmortimer      3.5       3.5           4.0      Missing
# ..               ...      ...       ...           ...          ...
# 638  danyellowconnor      3.5       3.5      Late 4.0     Late 1.5
# 639           pzng97      2.5       1.5           2.0          2.0
# 640       suttercain  Missing   Missing       Missing      Missing
# 641           remobo  Missing   Missing       Missing      Missing
# 642       ezracubero      4.5       4.5           3.0      Missing
#
#     nickel-boys wicked-2024 maria-2024 oppenheimer-2023 poor-things-2023  ...  \
# 0           4.0         3.0    Missing              4.5              4.5  ...
# ...
