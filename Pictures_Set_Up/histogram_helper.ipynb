# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# User Bell Curve Picture

# %%
df = pd.read_csv('C:/Users/Shmoops/Desktop/Conda_Stuff/python-prep-backup/fall-2025-predicting-movie-success/source_data/popular_users_ratings_1k.csv')
#df
## use user = [deathproof]

#df_bell_user = df.iloc[3]

ratings = [0.5, 1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5]
scores_bell = [26/2546, 96/2546, 121/2546, 207/2546, 279/2546, 453/2546, 529/2546, 446/2546, 258/2546, 131/2546]
scores_nonbell = [1295/7594, 1035/7594, 569/7594, 624/7594, 671/7594, 798/7594, 417/7594, 429/7594, 514/7594, 1242/7594]

plt.plot(ratings, scores_bell)
plt.savefig('bell_user_deathproof.png')
#plt.scatter(ratings, scores_nonbell)
df
# Out:
#              username   0.5     1  1.5    2  2.5    3  3.5    4  4.5     5  \
# 0            kurstboy    31    57   57  108  116  214  390  497  389   215
# 1        schaffrillas    27    83   78   84  110  199  238  253  154    82
# 2                 jay    39    66  103  149  189  256  282  303   82    29
# 3          deathproof    26    96  121  207  279  453  529  446  258   131
# 4        davidehrlich    37    72  191  341  454  724  622  451  190    97
# ...               ...   ...   ...  ...  ...  ...  ...  ...  ...  ...   ...
# 2226     markmarshall    37    63   98  147  227  311  405  333  176    86
# 2227  arkhamknightrid  1295  1035  569  624  671  798  417  429  514  1242
# 2228           faisty     9    10    9   47  101  122  155  240  192   157
# 2229    thejosiemarie     7    13   10   71   87  274  173  389   77   164
# 2230       cinecinzia    10    25   21  169  191  343  309  293   63   152
#
#       total
# 0      2074
# 1      1308
# 2      1498
# 3      2546
# 4      3179
# ...     ...
# 2226   1883
# 2227   7594
# 2228   1042
# 2229   1265
# 2230   1576
#
# [2231 rows x 12 columns]

# %% [markdown]
# User Not Bell Curve Picture

# %%
## use user = [arkhamknightrid]
plt.plot(ratings, scores_nonbell)
plt.savefig('nonbell_user_arkhamknightride.png')

# %%
## L2 Distance Plot

df = pd.read_csv('C:/Users/Shmoops/Desktop/Conda_Stuff/python-prep-backup/fall-2025-predicting-movie-success/Post_Award_Analysis/Sorted_Mean_Differences.csv')

fig = df.plot(legend=None)
fig.set(xlabel= 'Movie', ylabel='Mean Difference', title="Total Change in Rating")

total_change = fig.get_figure()

total_change.savefig("mean_change.png")

df
# Out:
#                moviename  mean_diff
# 0             green-book      -0.47
# 1      bohemian-rhapsody      -0.34
# 2                   lion      -0.28
# 3     the-imitation-game      -0.25
# 4         hidden-figures      -0.21
# ..                   ...        ...
# 58          dunkirk-2017       0.43
# 59          eighth-grade       0.50
# 60  call-me-by-your-name       0.52
# 61               boyhood       0.68
# 62          emilia-perez       1.54
#
# [63 rows x 2 columns]

# %%
import seaborn as sns

# %%
df
# Out:
#                              Unnamed: 0  mod_bell_dist
# 0                           wicked-2024      -0.382171
# 1                          emilia-perez      -0.359626
# 2                               boyhood      -0.322758
# 3                      oppenheimer-2023      -0.299263
# 4                     mad-max-fury-road      -0.282570
# ..                                  ...            ...
# 58                    bohemian-rhapsody       0.124183
# 59  all-quiet-on-the-western-front-2022       0.125708
# 60                       hidden-figures       0.125845
# 61                                 lion       0.139835
# 62                           green-book       0.192447
#
# [63 rows x 2 columns]

# %%
plot_names = []
plot_dict = {}

movie_names_mod = {
    'movie_names_mod0':['Wicked', 'Emilia Perez', 'Boyhood', 'Oppenheimer', 'Mad Max Fury Road', 'Call Me By Your Name', 'Dunkirk'], 
    'movie_names_mod1': ['Eighth Grade', 'Lady Bird', 'Dune', 'The Fabelmans', 'Once Upon A Time', 'Nomadland', 'Poor Things'],
    'movie_names_mod2': ['Roma', 'Mank', 'Anora', 'Borat 2', 'Moonlight', 'Blade Runner 2049', 'Get Out'],
    'movie_names_mod3': ['Parasite', 'Tick Tick Boom', 'Grand Budapest Hotel', 'Black Panther', 'The Brutalist', 'West Side Story', 'Palm Springs'],
    'movie_names_mod4' : ['The Martian', 'Shape of Water', 'Can You Ever Forgive Me', 'Dont Look Up', 'Everything Everywhere', 'Three Billboards', 'Women Talking'], 
    'movie_names_mod5' : ['Promising Young Woman', 'Nickel Boys', 'Power of the Dog', 'La La Land', 'Spotlight', 'Arrival', 'Banshees of Inisherin'], 
    'movie_names_mod6' : ['Top Gun Maverick', 'American Fiction', 'Cold War', 'Trial of the Chicago 7', 'King Richard', 'Conclave', 'Maria'], 
    'movie_names_mod7' : ['The Holdovers', 'The Big Short', 'Coda', 'I, Tonya', 'Birdman', 'Imitation Game', '1917'], 
    'movie_names_mod8' : ['Jojo Rabbit', 'The Revenant', 'Bohemian Rhapsody', 'All Quiet', 'Hidden Figures', 'Lion', 'Green Book'], 
}

movie_names = {
    'movie_names0':['Conclave', 'Maria', 'King Richard', 'Trial of the Chicago 7', 'Cold War', 'American Fiction', 'Top Gun Maverick'], 
    'movie_names1': ['Banshees of Inisherin', 'The Holdovers', 'The Big Short', 'Coda', 'I, Tonya', 'Birdman', 'Arrival'],
    'movie_names2': ['Spotlight', 'Imitation Game', '1917', 'La La Land', 'Power of the Dog', 'Nickel Boys', 'Jojo Rabbit'],
    'movie_names3': ['Promising Young Woman', 'Women Talking', 'Three Billboards', 'The Revenant', 'Everything Everywhere', 'Dont Look Up', 'Can You Ever Forgive Me'],
    'movie_names4' : ['Bohemian Rhapsody', 'All Quiet', 'Hidden Figures', 'Shape of Water', 'The Martian', 'Palm Springs', 'West Side Story'], 
    'movie_names5' : ['The Brutalist', 'Grand Budapest Hotel', 'Lion', 'Tick Tick Boom', 'Parasite', 'Get Out', 'Blade Runner 2049'], 
    'movie_names6' : ['Moonlight', 'Borat 2', 'Anora', 'Mank', 'Roma', 'Poor Things', 'Nomadland'], 
    'movie_names7' : ['Green Book', 'Once Upon A Time', 'Fabelmans', 'Dune', 'Lady Bird', 'Eighth Grade', 'Dunkirk'], 
    'movie_names8' : ['Call Me By Your Name', 'Mad Max Fury Road', 'Oppenheimer', 'Boyhood', 'Emilia Perez', 'Wicked', ''], 
               }

for i in range(9):
    plot_names.append('plot_' + str(i))
    indices = [7*i + j for j in range(7)]
    subindices = [b for b in range(7)]
    colors = [10*c for c in indices]
    df_restr = df.iloc[indices]
    x = indices
    y = df_restr['mod_bell_dist']
    #movies_to_use = [df_restr['Unnamed: 0'].iloc[k] for k in range(7)]
    titles = movie_names_mod['movie_names_mod' + str(i)]

    fig, ax = plt.subplots(figsize=(5,5))
    ax = sns.scatterplot(x=indices,y=y,hue = titles,data = df_restr, legend='full')
    ax.legend(loc='best')
    ax.set(ylabel='Change in Rating')

    newimage = fig.get_figure()
    newimage.savefig('plot_mod_' + str(i) + '.png')
    

    # for l in range(7):
    #     ax.annotate(titles[l], xy= (subindices[l], y[l]))
    #plot_dict[plot_names[i]] = [ax]

# %%
df
# Out:
#                moviename  mean_diff
# 0             green-book      -0.47
# 1      bohemian-rhapsody      -0.34
# 2                   lion      -0.28
# 3     the-imitation-game      -0.25
# 4         hidden-figures      -0.21
# ..                   ...        ...
# 58          dunkirk-2017       0.43
# 59          eighth-grade       0.50
# 60  call-me-by-your-name       0.52
# 61               boyhood       0.68
# 62          emilia-perez       1.54
#
# [63 rows x 2 columns]

# %%
df = pd.read_csv('C:/Users/Shmoops/Desktop/Conda_Stuff/python-prep-backup/fall-2025-predicting-movie-success/Post_Award_Analysis/Sorted_Mean_Diff_Flip.csv')

fig = df.plot(legend=None)
fig.set(xlabel= 'Movie', ylabel='Mean Difference', title="Total Change in Rating")

total_change = fig.get_figure()

total_change.savefig("mean_change_flip.png")

df
# Out:
#                moviename  mean_diff
# 0           emilia-perez      -1.54
# 1                boyhood      -0.68
# 2   call-me-by-your-name      -0.52
# 3           eighth-grade      -0.50
# 4      mad-max-fury-road      -0.43
# ..                   ...        ...
# 58        hidden-figures       0.21
# 59    the-imitation-game       0.25
# 60                  lion       0.28
# 61     bohemian-rhapsody       0.34
# 62            green-book       0.47
#
# [63 rows x 2 columns]

# %%
plot_names = []
plot_dict = {}

movie_names_mean = {
    'movie_names_mean0':['Green Book', 'Bohemian Rhapsody', 'Lion', 'Imitation Game', 'Hidden Figures', 'All Quiet', 'Jojo Rabbit'], 
    'movie_names_mean1': ['I, Tonya', 'Birdman', 'The Holdovers', 'Coda', 'Conclave', 'Maria', 'The Revenant'],
    'movie_names_mean2': ['The Big Short', '1917', 'Parasite', 'Three Billboards', 'Trial of the Chicago 7', 'Grand Budapest Hotel', 'Arrival'],
    'movie_names_mean3': ['Get Out', 'King Richard', 'Spotlight', 'Top Gun Maverick', 'Cold War', 'Banshees of Inisherin', 'American Fiction'],
    'movie_names_mean4' : ['Nickel Boys', 'Black Panther', 'Promising Young Woman', 'Power of the Dog', 'La La Land', 'The Martian', 'Dont Look Up'], 
    'movie_names_mean5' : ['Blade Runner 2049', 'Can You Ever Forgive Me', 'Everything Everywhere', 'Palm Springs', 'Women Talking', 'Tick Tick Boom', 'Moonlight'], 
    'movie_names_mean6' : ['The Brutalist', 'Dune', 'West Side Story', 'Shape of Water', 'Fabelmans', 'Oppenheimer', 'Roma'], 
    'movie_names_mean7' : ['Borat 2', 'Poor Things', 'Once Upon a Time', 'Anora', 'Nomadland', 'Lady Bird', 'Mank'], 
    'movie_names_mean8' : ['Wicked', 'Mad Max Fury Road', 'Dunkirk', 'Eighth Grade', 'Call Me By Your Name', 'Boyhood', 'Emilia Perez'], 
}

movie_names_flip = {

    'movie_names_flip0': ['Emilia Perez', 'Boyhood', 'Call Me By Your Name', 'Eighth Grade', 'Dunkirk', 'Mad Max Fury Road', 'Wicked'],
    'movie_names_flip1' : ['Mank', 'Lady Bird', 'Nomadland', 'Anora', 'Once Upon a Time', 'Poor Things', 'Borat 2'], 
    'movie_names_flip2' : ['Roma', 'Oppenheimer', 'Fabelmans', 'Shape of Water', 'West Side Story', 'Dune', 'The Brutalist'],
    'movie_names_flip3' : ['Moonlight', 'Tick Tick Boom', 'Women Talking', 'Palm Springs', 'Everything Everywhere', 'Can You Ever Forgive Me', 'Blade Runner 2049'], 
    'movie_names_flip4' : ['Dont Look Up', 'The Martian', 'La La Land', 'Power of the Dog', 'Promising Young Woman', 'Black Panther', 'Nickel Boys'], 
    'movie_names_flip5': ['American Fiction', 'Banshees of Inisherin', 'Cold War', 'Top Gun Maverick', 'Spotlight', 'King Richard', 'Get Out'],
    'movie_names_flip6': ['Arrival', 'Grand Budapest Hotel', 'Trial of the Chicago 7', 'Three Billboards', 'Parasite', '1917', 'The Big Short'],
    'movie_names_flip7': ['The Revenant', 'Maria', 'Conclave', 'Coda', 'The Holdovers', 'Birdman', 'I, Tonya'],
    'movie_names_flip8':['Jojo Rabbit', 'All Quiet', 'Hidden Figures', 'Imitation Game', 'Lion', 'Bohemian Rhapsody', 'Green Book'],

    

}

for i in range(9):
    #plot_names.append('mean_plot_' + str(i))
    indices = [7*i + j for j in range(7)]
    subindices = [b for b in range(7)]
    colors = [10*c for c in indices]
    df_restr = df.iloc[indices]
    x = indices
    y = df_restr['mean_diff']
    #movies_to_use = [df_restr['Unnamed: 0'].iloc[k] for k in range(7)]
    titles = movie_names_flip['movie_names_flip' + str(i)]

    fig, ax = plt.subplots(figsize=(5,5))
    ax = sns.scatterplot(x=indices,y=y,hue = titles,data = df_restr, legend='full')
    ax.legend(loc='best')
    ax.set(ylabel='Change in Mean')

    newimage = fig.get_figure()
    newimage.savefig('plot_mean_' + str(i) + '.png')
